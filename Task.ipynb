# %% [markdown]
# ## Data Analytics 1 - Machine Learning Project

# %% [markdown]
# <span style="font-size:30px;">**Instructions:**</span>
#
# **1. The exptected outcome of this project is to do ML modelling similar to what you find in the notebooks in [Kaggle](https://www.kaggle.com/). To that, your work should include proper dataset loading, EDA, feature engineering and building multiple ML models. You should show the effort about how you have improved the metrics by selecting\optimizing the models. Equally important is describing why you followed the steps in your solution. At the end of your notebook, it is expected to point out what is the best model and why.**
#
# **2. The submission should be done on a dedicated activity on ecampus. It is shown on the home page of the module on ecampus.**
#
# **3. Submitting a solution as links to Google Drive or Onedrive or any similar way is not accepted. Only folder/files submission is allowed on ecampus.**
#
# **4. Your solution should be your own work. Group work is not allowed.**
#
# **5. Here is [the link](https://www.kaggle.com/datasets/jarupula/machine-hack/data) to your dataset. You can download it by clicking on Download button.**
#
# **6. In the download, there are two datasets: one for training and one for testing. You should run the testing one on the concluded best model at the end.**
#
# **6. The due time to submit your solution on ecampus on Friday 08.08.2025 at 11:59 PM.**
